# %% [markdown]
# # Practice Session 2

# %% [markdown]
# The goal of this project is to build a cat family classification model using convolutional neural networks (CNN) and the Fast.ai library. This model will be able to accurately classify between lion, tiger, cougar, caracal, cheetah and ocelot images. We will use transfer learning with a pre-trained ResNet34 architecture as our base for training the model on our dataset of cats from each species in order to achieve high accuracy results quickly and efficiently.
#
# ### Video
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ASrefAVEcJk" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#
#
# ### Objectives
#
# 1. Install and Import Required libraries
# 2. How Make Your Own Data
# 3. Verify the Data
# 4. Make Data Loaders
# 5. Make Learner
# 6. Train the Model
# 7. Interpretation
#
#
# ###  Highlights
#
# Following were the highlight's:
#
# 1. Remaking walkwithfastai course ( https://walkwithfastai.com/ )
# 2. Lesson One Part 2: Cat Family Images classification
#
#
#
#
# ### Resources :
#
#
# 1. [Slides](https://drive.google.com/drive/folders/1Iq_Fds9ngbAgIN6sqjy0U3m4qqFxmqiG?fbclid=IwAR1pY3W5_QntRz27L10-wQvGMY80Eb21xHxH93CdEarA9BOOVYlV5zETZEE) [Notes](https://drive.google.com/drive/folders/1qT9fycek2E9jm2fVsgAYOaJjy0nyNIfY) [Python Notebook](https://github.com/Doha-Tarek/Practical-Deep-Learning-For-Coders/blob/main/Cat_Family_Classification.ipynb)
# 2. [Original Lesson](https://walkwithfastai.com/Introduction)
# 3. [Amazon Book](https://www.amazon.com/Deep-Learning-Coders-fastai-PyTorch/dp/1492045527)
# 4. [Free Book Version](https://github.com/fastai/fastbook)
#
#
# ## Acknowledgements
#
# Special Thanks to @Jeremy Howard
